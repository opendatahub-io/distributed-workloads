# %%
# Import pieces from codeflare-sdk
from codeflare_sdk.cluster.cluster import Cluster, ClusterConfiguration
from codeflare_sdk.job.jobs import DDPJobDefinition

# %%
# Create our cluster and submit appwrapper
cluster = Cluster(ClusterConfiguration(namespace='opendatahub', name='mnisttest', min_worker=1, max_worker=1, min_cpus=1, max_cpus=1, min_memory=4, max_memory=4, gpu=0, instascale=False))

# %%
# Bring up the cluster
cluster.up()

# %%
cluster.wait_ready()

# %%
cluster.status()

# %%
cluster.details()

# %%
job = DDPJobDefinition(script="mnist.py", scheduler_args={"requirements": "requirements.txt"}).submit(cluster)
