# %%
# Import pieces from codeflare-sdk
from codeflare_sdk.job.jobs import DDPJobDefinition

# %%
job = DDPJobDefinition(name="mnistjob", script="mnist.py", scheduler_args={"namespace": "opendatahub"}, j="1x1", gpu=0, cpu=1, memMB=8000, image="quay.io/michaelclifford/mnist-test:latest").submit()
